# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('../src/'))

# %%
from postgis_raster_bridge import readDataByArea

# %%
readDataByArea(
    latU=16.903489,
    lonU=41.05911,
    latD=16.821519,
    lonD=41.152986,
    tipoDati='pericolositaFrane',
    cellSize=25,
    positive=1,
    negative=0,
    nodata=254,
    out_srid=4326,
    circle=False
)
# Out:
# --Processing pericolositaFrane
# {'jobId': 58,
#  'parameters': {'latU': 16.903489,
#   'lonU': 41.05911,
#   'latD': 16.821519,
#   'lonD': 41.152986,
#   'cellSize': 25,
#   'tipoDati': ['pericolositaFrane']},
#  'tipoDati': {'pericolositaFrane': {'ouputGeotiffFile': 'http://localhost:5000//sevara/v1/jobs/readDataByArea/58/pericolositaFrane.tiff',
#    'outputGeotiffFilepath': 'D:\\Backup\\sevara\\jobs\\58\\pericolositaFrane.tiff',
#    'timeTakenInfoQuery': 0.3921394348144531,
#    'timeTakenRasterQuery': 0.3764808177947998,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'layer_name': 'Elevata P3',
#      'table_name': 'isp_frane',
#      'layer_area': 37479.66710446919},
#     {'layer_id': 2,
#      'layer_name': 'Molto elevata P4',
#      'table_name': 'isp_frane',
#      'layer_area': 24984.933771956086}],
#    'total_area': 62464.60087642528,
#    'rasterInfo': {'cellSizeX_Meters': 25,
#     'cellSizeY_meters': 25,
#     'cellSizeX_dd': 0.00019609619029165923,
#     'cellSizeY_dd': 0.0002461398756614878,
#     'Rows': 419,
#     'Cols': 382,
#     'Bands': 2}}},
#  'outputsToProduce': ['pericolositaFrane'],
#  'rasterInfoCommon': {'cellSizeX_Meters': 25,
#   'cellSizeY_meters': 25,
#   'cellSizeX_dd': 0.00019609619029165923,
#   'cellSizeY_dd': 0.0002461398756614878,
#   'Rows': 419,
#   'Cols': 382},
#  'time_taken_total': 0.9500815868377686,
#  'time_units': 'Seconds'}

# %%
readDataByArea(
    latU=16.903489,
    lonU=41.05911,
    latD=16.821519,
    lonD=41.152986,
    tipoDati='pericolositaIdraulica',
    cellSize=25,
    positive=1,
    negative=0,
    nodata=254,
    out_srid=4326,
    circle=False
)
# Out:
# --Processing pericolositaIdraulica
# {'jobId': 59,
#  'parameters': {'latU': 16.903489,
#   'lonU': 41.05911,
#   'latD': 16.821519,
#   'lonD': 41.152986,
#   'cellSize': 25,
#   'tipoDati': ['pericolositaIdraulica']},
#  'tipoDati': {'pericolositaIdraulica': {'ouputGeotiffFile': 'http://localhost:5000//sevara/v1/jobs/readDataByArea/59/pericolositaIdraulica.tiff',
#    'outputGeotiffFilepath': 'D:\\Backup\\sevara\\jobs\\59\\pericolositaIdraulica.tiff',
#    'timeTakenInfoQuery': 0.739722728729248,
#    'timeTakenRasterQuery': 0.7787497043609619,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'layer_name': "Aree a pericolosita' idraulica bassa P1",
#      'table_name': 'isp_idraulica_p1',
#      'layer_area': 3022257.11208891},
#     {'layer_id': 2,
#      'layer_name': "Aree a pericolosita' idraulica media P2",
#      'table_name': 'isp_idraulica_p2',
#      'layer_area': 2820448.2424260955},
#     {'layer_id': 3,
#      'layer_name': "Aree a pericolosita' idraulica elevata P3",
#      'table_name': 'isp_idraulica_p3',
#      'layer_area': 2277311.812697961}],
#    'total_area': 8120017.167212966,
#    'rasterInfo': {'cellSizeX_Meters': 25,
#     'cellSizeY_meters': 25,
#     'cellSizeX_dd': 0.00019609619029165923,
#     'cellSizeY_dd': 0.0002461398756614878,
#     'Rows': 419,
#     'Cols': 382,
#     'Bands': 3}}},
#  'outputsToProduce': ['pericolositaIdraulica'],
#  'rasterInfoCommon': {'cellSizeX_Meters': 25,
#   'cellSizeY_meters': 25,
#   'cellSizeX_dd': 0.00019609619029165923,
#   'cellSizeY_dd': 0.0002461398756614878,
#   'Rows': 419,
#   'Cols': 382},
#  'time_taken_total': 1.6746056079864502,
#  'time_units': 'Seconds'}

# %%
readDataByArea(
    latU=16.529081,
    lonU=40.842014,
    latD=16.573026,
    lonD=40.809540,
    tipoDati='tutti',
    cellSize=10,
    positive=1,
    negative=0,
    nodata=254,
    out_srid=4326,
    circle=False
)
# Out:
# --Processing attivita
# --Processing superficieEdificato
# --Processing superficieAreeServizio
# --Processing struttureVarie
# --Processing pericolositaFrane
# --Processing pericolositaIdraulica
# {'jobId': 63,
#  'parameters': {'latU': 16.529081,
#   'lonU': 40.842014,
#   'latD': 16.573026,
#   'lonD': 40.80954,
#   'cellSize': 10,
#   'tipoDati': ['tutti']},
#  'tipoDati': {'attivita': {'ouputGeotiffFile': 'http://localhost:5000/sevara/v1/jobs/readDataByArea/63/attivita.tiff',
#    'outputGeotiffFilepath': '/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/63/attivita.tiff',
#    'timeTakenInfoQuery': 0.1796398162841797,
#    'timeTakenRasterQuery': 19.891759395599365,
#    'time_units': 'Seconds',
#    'comuni': [{'comune_code': 72004,
#      'comune_name': 'Altamura',
#      'comune_area': 40475245.8660624,
#      'area_units': 'Sq. Meter',
#      'comune_population': 61195.3095485999,
#      'comune_area_total': 1294109896.68489,
#      'comune_pop_total': 69431.0,
#      'attivita_total': 168,
#      'attivita': [{'ateco3_code': 11,
#        'ateco3_name': 'COLTIVAZIONE DI COLTURE AGRICOLE NON PERMANENTI',
#        'num_unita': 1,
#        'addett': 0},
#       {'ateco3_code': 16,
#        'ateco3_name': "ATTIVITА DI SUPPORTO ALL'AGRICOLTURA E ATTIVITА SUCCESSIVE ALLA RACCOLTA",
#        'num_unita': 8,
#        'addett': 14},
#       {'ateco3_code': 24,
#        'ateco3_name': 'SERVIZI DI SUPPORTO PER LA SILVICOLTURA',
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 81,
#        'ateco3_name': 'ESTRAZIONE DI PIETRA, SABBIA E ARGILLA',
#        'num_unita': 1,
#        'addett': 3},
#       {'ateco3_code': 104,
#        'ateco3_name': 'PRODUZIONE DI OLI E GRASSI VEGETALI E ANIMALI',
#        'num_unita': 7,
#        'addett': 13},
#       {'ateco3_code': 105,
#        'ateco3_name': 'INDUSTRIA LATTIERO-CASEARIA',
#        'num_unita': 23,
#        'addett': 63},
#       {'ateco3_code': 106,
#        'ateco3_name': 'LAVORAZIONE DELLE GRANAGLIE, PRODUZIONE DI AMIDI E DI PRODOTTI AMIDACEI',
#        'num_unita': 11,
#        'addett': 133},
#       {'ateco3_code': 107,
#        'ateco3_name': 'PRODUZIONE DI PRODOTTI DA FORNO E FARINACEI',
#        'num_unita': 108,
#        'addett': 523},
#       {'ateco3_code': 108,
#        'ateco3_name': 'PRODUZIONE DI ALTRI PRODOTTI ALIMENTARI',
#        'num_unita': 5,
#        'addett': 16},
#       {'ateco3_code': 109,
#        'ateco3_name': "PRODUZIONE DI PRODOTTI PER L'ALIMENTAZIONE DEGLI ANIMALI",
#        'num_unita': 3,
#        'addett': 28},
#       {'ateco3_code': 110,
#        'ateco3_name': 'INDUSTRIA DELLE BEVANDE',
#        'num_unita': 2,
#        'addett': 4},
#       {'ateco3_code': 132,
#        'ateco3_name': 'TESSITURA',
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 139,
#        'ateco3_name': 'ALTRE INDUSTRIE TESSILI',
#        'num_unita': 24,
#        'addett': 81},
#       {'ateco3_code': 141,
#        'ateco3_name': 'CONFEZIONE DI ARTICOLI DI ABBIGLIAMENTO (ESCLUSO ABBIGLIAMENTO IN PELLICCIA)',
#        'num_unita': 19,
#        'addett': 39},
#       {'ateco3_code': 143,
#        'ateco3_name': 'FABBRICAZIONE DI ARTICOLI DI MAGLIERIA',
#        'num_unita': 3,
#        'addett': 7},
#       {'ateco3_code': 151,
#        'ateco3_name': 'PREPARAZIONE E CONCIA DEL CUOIO; FABBRICAZIONE DI ARTICOLI DA VIAGGIO, BORSE, PELLETTERIA E SELLERIA; PREPARAZIONE E TINTURA DI PELLICCE',
#        'num_unita': 1,
#        'addett': 0},
#       {'ateco3_code': 152,
#        'ateco3_name': 'FABBRICAZIONE DI CALZATURE',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 161,
#        'ateco3_name': 'TAGLIO E PIALLATURA DEL LEGNO',
#        'num_unita': 20,
#        'addett': 53},
#       {'ateco3_code': 162,
#        'ateco3_name': 'FABBRICAZIONE DI PRODOTTI IN LEGNO, SUGHERO, PAGLIA E MATERIALI DA INTRECCIO',
#        'num_unita': 48,
#        'addett': 198},
#       {'ateco3_code': 171,
#        'ateco3_name': 'FABBRICAZIONE DI PASTA-CARTA, CARTA E CARTONE',
#        'num_unita': 2,
#        'addett': 2},
#       {'ateco3_code': 172,
#        'ateco3_name': 'FABBRICAZIONE DI ARTICOLI DI CARTA E CARTONE',
#        'num_unita': 3,
#        'addett': 4},
#       {'ateco3_code': 181,
#        'ateco3_name': 'STAMPA E SERVIZI CONNESSI ALLA STAMPA',
#        'num_unita': 19,
#        'addett': 34},
#       {'ateco3_code': 201,
#        'ateco3_name': 'FABBRICAZIONE DI PRODOTTI CHIMICI DI BASE, DI FERTILIZZANTI E COMPOSTI AZOTATI, DI MATERIE PLASTICHE E GOMMA SINTETICA IN FORME PRIMARIE',
#        'num_unita': 3,
#        'addett': 2},
#       {'ateco3_code': 203,
#        'ateco3_name': 'FABBRICAZIONE DI PITTURE, VERNICI E SMALTI, INCHIOSTRI DA STAMPA E ADESIVI SINTETICI (MASTICI)',
#        'num_unita': 2,
#        'addett': 7},
#       {'ateco3_code': 204,
#        'ateco3_name': 'FABBRICAZIONE DI SAPONI E DETERGENTI, DI PRODOTTI PER LA PULIZIA E LA LUCIDATURA, DI PROFUMI E COSMETICI',
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 221,
#        'ateco3_name': 'FABBRICAZIONE DI ARTICOLI IN GOMMA',
#        'num_unita': 6,
#        'addett': 70},
#       {'ateco3_code': 222,
#        'ateco3_name': 'FABBRICAZIONE DI ARTICOLI IN MATERIE PLASTICHE',
#        'num_unita': 23,
#        'addett': 192},
#       {'ateco3_code': 231,
#        'ateco3_name': 'FABBRICAZIONE DI VETRO E DI PRODOTTI IN VETRO',
#        'num_unita': 2,
#        'addett': 6},
#       {'ateco3_code': 234,
#        'ateco3_name': 'FABBRICAZIONE DI ALTRI PRODOTTI IN PORCELLANA E IN CERAMICA',
#        'num_unita': 3,
#        'addett': 4},
#       {'ateco3_code': 236,
#        'ateco3_name': 'FABBRICAZIONE DI PRODOTTI IN CALCESTRUZZO, CEMENTO E GESSO',
#        'num_unita': 3,
#        'addett': 31},
#       {'ateco3_code': 237,
#        'ateco3_name': 'TAGLIO, MODELLATURA E FINITURA DI PIETRE',
#        'num_unita': 18,
#        'addett': 99},
#       {'ateco3_code': 243,
#        'ateco3_name': "FABBRICAZIONE DI ALTRI PRODOTTI DELLA PRIMA TRASFORMAZIONE DELL'ACCIAIO",
#        'num_unita': 7,
#        'addett': 38},
#       {'ateco3_code': 251,
#        'ateco3_name': 'FABBRICAZIONE DI ELEMENTI DA COSTRUZIONE IN METALLO',
#        'num_unita': 51,
#        'addett': 213},
#       {'ateco3_code': 252,
#        'ateco3_name': 'FABBRICAZIONE DI CISTERNE, SERBATOI, RADIATORI E CONTENITORI IN METALLO',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 256,
#        'ateco3_name': 'TRATTAMENTO E RIVESTIMENTO DEI METALLI; LAVORI DI MECCANICA GENERALE',
#        'num_unita': 4,
#        'addett': 15},
#       {'ateco3_code': 257,
#        'ateco3_name': 'FABBRICAZIONE DI ARTICOLI DI COLTELLERIA, UTENSILI E OGGETTI DI FERRAMENTA',
#        'num_unita': 1,
#        'addett': 8},
#       {'ateco3_code': 259,
#        'ateco3_name': 'FABBRICAZIONE DI ALTRI PRODOTTI IN METALLO',
#        'num_unita': 7,
#        'addett': 40},
#       {'ateco3_code': 261,
#        'ateco3_name': 'FABBRICAZIONE DI COMPONENTI ELETTRONICI E SCHEDE ELETTRONICHE',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 262,
#        'ateco3_name': 'FABBRICAZIONE DI COMPUTER E UNITА PERIFERICHE',
#        'num_unita': 4,
#        'addett': 16},
#       {'ateco3_code': 266,
#        'ateco3_name': 'FABBRICAZIONE DI STRUMENTI PER IRRADIAZIONE, APPARECCHIATURE ELETTROMEDICALI ED ELETTROTERAPEUTICHE',
#        'num_unita': 3,
#        'addett': 17},
#       {'ateco3_code': 267,
#        'ateco3_name': 'FABBRICAZIONE DI STRUMENTI OTTICI E ATTREZZATURE FOTOGRAFICHE',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 271,
#        'ateco3_name': "FABBRICAZIONE DI MOTORI, GENERATORI E TRASFORMATORI ELETTRICI E DI APPARECCHIATURE PER LA DISTRIBUZIONE E IL CONTROLLO DELL'ELETTRICITА",
#        'num_unita': 2,
#        'addett': 27},
#       {'ateco3_code': 279,
#        'ateco3_name': 'FABBRICAZIONE DI ALTRE APPARECCHIATURE ELETTRICHE',
#        'num_unita': 2,
#        'addett': 6},
#       {'ateco3_code': 282,
#        'ateco3_name': 'FABBRICAZIONE DI ALTRE MACCHINE DI IMPIEGO GENERALE',
#        'num_unita': 7,
#        'addett': 17},
#       {'ateco3_code': 283,
#        'ateco3_name': "FABBRICAZIONE DI MACCHINE PER L'AGRICOLTURA E LA SILVICOLTURA",
#        'num_unita': 3,
#        'addett': 22},
#       {'ateco3_code': 284,
#        'ateco3_name': 'FABBRICAZIONE DI MACCHINE PER LA FORMATURA DEI METALLI E DI ALTRE MACCHINE UTENSILI',
#        'num_unita': 2,
#        'addett': 6},
#       {'ateco3_code': 289,
#        'ateco3_name': 'FABBRICAZIONE DI ALTRE MACCHINE PER IMPIEGHI SPECIALI',
#        'num_unita': 7,
#        'addett': 73},
#       {'ateco3_code': 292,
#        'ateco3_name': 'FABBRICAZIONE DI CARROZZERIE PER AUTOVEICOLI, RIMORCHI E SEMIRIMORCHI',
#        'num_unita': 1,
#        'addett': 4},
#       {'ateco3_code': 293,
#        'ateco3_name': 'FABBRICAZIONE DI PARTI ED ACCESSORI PER AUTOVEICOLI E LORO MOTORI',
#        'num_unita': 3,
#        'addett': 7},
#       {'ateco3_code': 310,
#        'ateco3_name': 'FABBRICAZIONE DI MOBILI',
#        'num_unita': 195,
#        'addett': 1606},
#       {'ateco3_code': 321,
#        'ateco3_name': 'FABBRICAZIONE DI GIOIELLERIA, BIGIOTTERIA E ARTICOLI CONNESSI; LAVORAZIONE DELLE PIETRE PREZIOSE',
#        'num_unita': 9,
#        'addett': 38},
#       {'ateco3_code': 325,
#        'ateco3_name': 'FABBRICAZIONE DI STRUMENTI E FORNITURE MEDICHE E DENTISTICHE',
#        'num_unita': 24,
#        'addett': 34},
#       {'ateco3_code': 329,
#        'ateco3_name': 'INDUSTRIE MANIFATTURIERE NCA',
#        'num_unita': 7,
#        'addett': 9},
#       {'ateco3_code': 331,
#        'ateco3_name': 'RIPARAZIONE E MANUTENZIONE DI PRODOTTI IN METALLO, MACCHINE ED APPARECCHIATURE',
#        'num_unita': 34,
#        'addett': 125},
#       {'ateco3_code': 332,
#        'ateco3_name': 'INSTALLAZIONE DI MACCHINE ED APPARECCHIATURE INDUSTRIALI',
#        'num_unita': 16,
#        'addett': 37},
#       {'ateco3_code': 351,
#        'ateco3_name': 'PRODUZIONE, TRASMISSIONE E DISTRIBUZIONE DI ENERGIA ELETTRICA',
#        'num_unita': 18,
#        'addett': 22},
#       {'ateco3_code': 360,
#        'ateco3_name': 'RACCOLTA, TRATTAMENTO E FORNITURA DI ACQUA',
#        'num_unita': 1,
#        'addett': 10},
#       {'ateco3_code': 381,
#        'ateco3_name': 'RACCOLTA DEI RIFIUTI',
#        'num_unita': 4,
#        'addett': 144},
#       {'ateco3_code': 383,
#        'ateco3_name': 'RECUPERO DEI MATERIALI',
#        'num_unita': 8,
#        'addett': 12},
#       {'ateco3_code': 412,
#        'ateco3_name': 'COSTRUZIONE DI EDIFICI RESIDENZIALI E NON RESIDENZIALI',
#        'num_unita': 454,
#        'addett': 1899},
#       {'ateco3_code': 421,
#        'ateco3_name': 'COSTRUZIONE DI STRADE E FERROVIE',
#        'num_unita': 3,
#        'addett': 9},
#       {'ateco3_code': 429,
#        'ateco3_name': 'COSTRUZIONE DI ALTRE OPERE DI INGEGNERIA CIVILE',
#        'num_unita': 7,
#        'addett': 648},
#       {'ateco3_code': 431,
#        'ateco3_name': 'DEMOLIZIONE E PREPARAZIONE DEL CANTIERE EDILE',
#        'num_unita': 13,
#        'addett': 29},
#       {'ateco3_code': 432,
#        'ateco3_name': 'INSTALLAZIONE DI IMPIANTI ELETTRICI, IDRAULICI ED ALTRI LAVORI DI COSTRUZIONE E INSTALLAZIONE',
#        'num_unita': 205,
#        'addett': 917},
#       {'ateco3_code': 433,
#        'ateco3_name': 'COMPLETAMENTO E FINITURA DI EDIFICI',
#        'num_unita': 378,
#        'addett': 956},
#       {'ateco3_code': 439,
#        'ateco3_name': 'ALTRI LAVORI SPECIALIZZATI DI COSTRUZIONE',
#        'num_unita': 16,
#        'addett': 77},
#       {'ateco3_code': 451,
#        'ateco3_name': 'COMMERCIO DI AUTOVEICOLI',
#        'num_unita': 32,
#        'addett': 91},
#       {'ateco3_code': 452,
#        'ateco3_name': 'MANUTENZIONE E RIPARAZIONE DI AUTOVEICOLI',
#        'num_unita': 112,
#        'addett': 275},
#       {'ateco3_code': 453,
#        'ateco3_name': 'COMMERCIO DI PARTI E ACCESSORI DI AUTOVEICOLI',
#        'num_unita': 25,
#        'addett': 61},
#       {'ateco3_code': 454,
#        'ateco3_name': 'COMMERCIO, MANUTENZIONE E RIPARAZIONE DI MOTOCICLI E RELATIVE PARTI ED ACCESSORI',
#        'num_unita': 3,
#        'addett': 6},
#       {'ateco3_code': 461,
#        'ateco3_name': 'INTERMEDIARI DEL COMMERCIO',
#        'num_unita': 141,
#        'addett': 163},
#       {'ateco3_code': 462,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO DI MATERIE PRIME AGRICOLE E DI ANIMALI VIVI",
#        'num_unita': 40,
#        'addett': 125},
#       {'ateco3_code': 463,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO DI PRODOTTI ALIMENTARI, BEVANDE E PRODOTTI DEL TABACCO",
#        'num_unita': 50,
#        'addett': 138},
#       {'ateco3_code': 464,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO DI BENI DI CONSUMO FINALE",
#        'num_unita': 49,
#        'addett': 84},
#       {'ateco3_code': 465,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO DI APPARECCHIATURE ICT",
#        'num_unita': 17,
#        'addett': 26},
#       {'ateco3_code': 466,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO DI ALTRI MACCHINARI, ATTREZZATURE E FORNITURE",
#        'num_unita': 26,
#        'addett': 88},
#       {'ateco3_code': 467,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO SPECIALIZZATO DI ALTRI PRODOTTI",
#        'num_unita': 54,
#        'addett': 216},
#       {'ateco3_code': 469,
#        'ateco3_name': "COMMERCIO ALL'INGROSSO NON SPECIALIZZATO",
#        'num_unita': 9,
#        'addett': 13},
#       {'ateco3_code': 471,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO IN ESERCIZI NON SPECIALIZZATI',
#        'num_unita': 80,
#        'addett': 303},
#       {'ateco3_code': 472,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI PRODOTTI ALIMENTARI, BEVANDE E TABACCO IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 177,
#        'addett': 309},
#       {'ateco3_code': 473,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI CARBURANTE PER AUTOTRAZIONE IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 24,
#        'addett': 79},
#       {'ateco3_code': 474,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI APPARECCHIATURE INFORMATICHE E PER LE TELECOMUNICAZIONI (ICT) IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 15,
#        'addett': 54},
#       {'ateco3_code': 475,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI ALTRI PRODOTTI PER USO DOMESTICO IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 112,
#        'addett': 231},
#       {'ateco3_code': 476,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI ARTICOLI CULTURALI E RICREATIVI IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 47,
#        'addett': 66},
#       {'ateco3_code': 477,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO DI ALTRI PRODOTTI IN ESERCIZI SPECIALIZZATI',
#        'num_unita': 249,
#        'addett': 554},
#       {'ateco3_code': 478,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO AMBULANTE',
#        'num_unita': 37,
#        'addett': 48},
#       {'ateco3_code': 479,
#        'ateco3_name': 'COMMERCIO AL DETTAGLIO AL DI FUORI DI NEGOZI, BANCHI E MERCATI',
#        'num_unita': 17,
#        'addett': 27},
#       {'ateco3_code': 491,
#        'ateco3_name': 'TRASPORTO FERROVIARIO DI PASSEGGERI (INTERURBANO)',
#        'num_unita': 3,
#        'addett': 30},
#       {'ateco3_code': 493,
#        'ateco3_name': 'ALTRI TRASPORTI TERRESTRI DI PASSEGGERI',
#        'num_unita': 9,
#        'addett': 129},
#       {'ateco3_code': 494,
#        'ateco3_name': 'TRASPORTO DI MERCI SU STRADA E SERVIZI DI TRASLOCO',
#        'num_unita': 268,
#        'addett': 1004},
#       {'ateco3_code': 521,
#        'ateco3_name': 'MAGAZZINAGGIO E CUSTODIA',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 522,
#        'ateco3_name': 'ATTIVITА DI SUPPORTO AI TRASPORTI',
#        'num_unita': 15,
#        'addett': 50},
#       {'ateco3_code': 531,
#        'ateco3_name': 'ATTIVITА POSTALI CON OBBLIGO DI SERVIZIO UNIVERSALE',
#        'num_unita': 3,
#        'addett': 93},
#       {'ateco3_code': 532,
#        'ateco3_name': 'ALTRE ATTIVITА POSTALI E DI CORRIERE',
#        'num_unita': 9,
#        'addett': 97},
#       {'ateco3_code': 551,
#        'ateco3_name': 'ALBERGHI E STRUTTURE SIMILI',
#        'num_unita': 6,
#        'addett': 13},
#       {'ateco3_code': 552,
#        'ateco3_name': 'ALLOGGI PER VACANZE E ALTRE STRUTTURE PER BREVI SOGGIORNI',
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 561,
#        'ateco3_name': 'RISTORANTI E ATTIVITА DI RISTORAZIONE MOBILE',
#        'num_unita': 136,
#        'addett': 568},
#       {'ateco3_code': 562,
#        'ateco3_name': 'FORNITURA DI PASTI PREPARATI (CATERING) E ALTRI SERVIZI DI RISTORAZIONE',
#        'num_unita': 7,
#        'addett': 115},
#       {'ateco3_code': 563,
#        'ateco3_name': 'BAR E ALTRI ESERCIZI SIMILI SENZA CUCINA',
#        'num_unita': 74,
#        'addett': 157},
#       {'ateco3_code': 581,
#        'ateco3_name': 'EDIZIONE DI LIBRI, PERIODICI ED ALTRE ATTIVITА EDITORIALI',
#        'num_unita': 3,
#        'addett': 4},
#       {'ateco3_code': 591,
#        'ateco3_name': 'ATTIVITА DI PRODUZIONE, POST-PRODUZIONE E DISTRIBUZIONE CINEMATOGRAFICA, DI VIDEO E DI PROGRAMMI TELEVISIVI, REGISTRAZIONI MUSICALI E SONORE',
#        'num_unita': 6,
#        'addett': 13},
#       {'ateco3_code': 601,
#        'ateco3_name': 'TRASMISSIONI RADIOFONICHE',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 611,
#        'ateco3_name': 'TELECOMUNICAZIONI FISSE',
#        'num_unita': 2,
#        'addett': 7},
#       {'ateco3_code': 619,
#        'ateco3_name': 'ALTRE ATTIVITА DI TELECOMUNICAZIONE',
#        'num_unita': 3,
#        'addett': 2},
#       {'ateco3_code': 620,
#        'ateco3_name': 'PRODUZIONE DI SOFTWARE, CONSULENZA INFORMATICA E ATTIVITА CONNESSE',
#        'num_unita': 20,
#        'addett': 36},
#       {'ateco3_code': 631,
#        'ateco3_name': 'ELABORAZIONE DEI DATI, HOSTING E ATTIVITА CONNESSE; PORTALI WEB',
#        'num_unita': 54,
#        'addett': 129},
#       {'ateco3_code': 639,
#        'ateco3_name': "ALTRE ATTIVITА DEI SERVIZI D'INFORMAZIONE",
#        'num_unita': 4,
#        'addett': 6},
#       {'ateco3_code': 641,
#        'ateco3_name': 'INTERMEDIAZIONE MONETARIA',
#        'num_unita': 17,
#        'addett': 499},
#       {'ateco3_code': 649,
#        'ateco3_name': 'ALTRE ATTIVITА DI SERVIZI FINANZIARI (ESCLUSE LE ASSICURAZIONI E I FONDI PENSIONE)',
#        'num_unita': 2,
#        'addett': 5},
#       {'ateco3_code': 651,
#        'ateco3_name': 'ASSICURAZIONI',
#        'num_unita': 1,
#        'addett': 9},
#       {'ateco3_code': 661,
#        'ateco3_name': 'ATTIVITА AUSILIARIE DEI SERVIZI FINANZIARI (ESCLUSE LE ASSICURAZIONI E I FONDI PENSIONE)',
#        'num_unita': 28,
#        'addett': 73},
#       {'ateco3_code': 662,
#        'ateco3_name': 'ATTIVITА AUSILIARIE DELLE ASSICURAZIONI E DEI FONDI PENSIONE',
#        'num_unita': 42,
#        'addett': 95},
#       {'ateco3_code': 681,
#        'ateco3_name': 'COMPRAVENDITA DI BENI IMMOBILI EFFETTUATA SU BENI PROPRI',
#        'num_unita': 15,
#        'addett': 12},
#       {'ateco3_code': 682,
#        'ateco3_name': 'AFFITTO E GESTIONE DI IMMOBILI DI PROPRIETА O IN LEASING',
#        'num_unita': 51,
#        'addett': 53},
#       {'ateco3_code': 683,
#        'ateco3_name': 'ATTIVITА IMMOBILIARI PER CONTO TERZI',
#        'num_unita': 19,
#        'addett': 26},
#       {'ateco3_code': 691,
#        'ateco3_name': 'ATTIVITА DEGLI STUDI LEGALI',
#        'num_unita': 151,
#        'addett': 195},
#       {'ateco3_code': 692,
#        'ateco3_name': 'CONTABILITА, CONTROLLO E REVISIONE CONTABILE, CONSULENZA IN MATERIA FISCALE E DEL LAVORO',
#        'num_unita': 141,
#        'addett': 209},
#       {'ateco3_code': 702,
#        'ateco3_name': 'ATTIVITА DI CONSULENZA GESTIONALE',
#        'num_unita': 14,
#        'addett': 24},
#       {'ateco3_code': 711,
#        'ateco3_name': 'ATTIVITА DEGLI STUDI DI ARCHITETTURA, INGEGNERIA ED ALTRI STUDI TECNICI',
#        'num_unita': 237,
#        'addett': 260},
#       {'ateco3_code': 712,
#        'ateco3_name': 'COLLAUDI ED ANALISI TECNICHE',
#        'num_unita': 16,
#        'addett': 31},
#       {'ateco3_code': 721,
#        'ateco3_name': "RICERCA E SVILUPPO SPERIMENTALE NEL CAMPO DELLE SCIENZE NATURALI E DELL'INGEGNERIA",
#        'num_unita': 3,
#        'addett': 2},
#       {'ateco3_code': 722,
#        'ateco3_name': 'RICERCA E SVILUPPO SPERIMENTALE NEL CAMPO DELLE SCIENZE SOCIALI E UMANISTICHE',
#        'num_unita': 2,
#        'addett': 1},
#       {'ateco3_code': 731,
#        'ateco3_name': 'PUBBLICITА',
#        'num_unita': 14,
#        'addett': 18},
#       {'ateco3_code': 732,
#        'ateco3_name': 'RICERCHE DI MERCATO E SONDAGGI DI OPINIONE',
#        'num_unita': 1,
#        'addett': 2},
#       {'ateco3_code': 741,
#        'ateco3_name': 'ATTIVITА DI DESIGN SPECIALIZZATE',
#        'num_unita': 12,
#        'addett': 12},
#       {'ateco3_code': 742,
#        'ateco3_name': 'ATTIVITА FOTOGRAFICHE',
#        'num_unita': 13,
#        'addett': 17},
#       {'ateco3_code': 743,
#        'ateco3_name': 'TRADUZIONE E INTERPRETARIATO',
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 749,
#        'ateco3_name': 'ALTRE ATTIVITА PROFESSIONALI, SCIENTIFICHE E TECNICHE NCA',
#        'num_unita': 37,
#        'addett': 65},
#       {'ateco3_code': 750,
#        'ateco3_name': 'SERVIZI VETERINARI',
#        'num_unita': 6,
#        'addett': 7},
#       {'ateco3_code': 771,
#        'ateco3_name': 'NOLEGGIO DI AUTOVEICOLI',
#        'num_unita': 3,
#        'addett': 5},
#       {'ateco3_code': 773,
#        'ateco3_name': 'NOLEGGIO DI ALTRE MACCHINE, ATTREZZATURE E BENI MATERIALI',
#        'num_unita': 10,
#        'addett': 17},
#       {'ateco3_code': 782,
#        'ateco3_name': 'ATTIVITА DELLE AGENZIE DI LAVORO TEMPORANEO (INTERINALE)',
#        'num_unita': 4,
#        'addett': 7},
#       {'ateco3_code': 791,
#        'ateco3_name': 'ATTIVITА DELLE AGENZIE DI VIAGGIO E DEI TOUR OPERATOR',
#        'num_unita': 14,
#        'addett': 23},
#       {'ateco3_code': 799,
#        'ateco3_name': 'ALTRI SERVIZI DI PRENOTAZIONE E ATTIVITА CONNESSE',
#        'num_unita': 2,
#        'addett': 1},
#       {'ateco3_code': 801,
#        'ateco3_name': 'SERVIZI DI VIGILANZA PRIVATA',
#        'num_unita': 5,
#        'addett': 70},
#       {'ateco3_code': 811,
#        'ateco3_name': 'SERVIZI INTEGRATI DI GESTIONE AGLI EDIFICI',
#        'num_unita': 1,
#        'addett': 26},
#       {'ateco3_code': 812,
#        'ateco3_name': 'ATTIVITА DI PULIZIA E DISINFESTAZIONE',
#        'num_unita': 35,
#        'addett': 187},
#       {'ateco3_code': 813,
#        'ateco3_name': 'CURA E MANUTENZIONE DEL PAESAGGIO',
#        'num_unita': 2,
#        'addett': 3},
#       {'ateco3_code': 821,
#        'ateco3_name': "ATTIVITА DI SUPPORTO PER LE FUNZIONI D'UFFICIO",
#        'num_unita': 3,
#        'addett': 25},
#       {'ateco3_code': 822,
#        'ateco3_name': 'ATTIVITА DEI CALL CENTER',
#        'num_unita': 1,
#        'addett': 15},
#       {'ateco3_code': 823,
#        'ateco3_name': 'ORGANIZZAZIONE DI CONVEGNI E FIERE',
#        'num_unita': 2,
#        'addett': 0},
#       {'ateco3_code': 829,
#        'ateco3_name': 'SERVIZI DI SUPPORTO ALLE IMPRESE NCA',
#        'num_unita': 30,
#        'addett': 86},
#       {'ateco3_code': 841,
#        'ateco3_name': 'AMMINISTRAZIONE PUBBLICA: AMMINISTRAZIONE GENERALE, ECONOMICA E SOCIALE',
#        'num_unita': 6,
#        'addett': 185},
#       {'ateco3_code': 842,
#        'ateco3_name': 'SERVIZI COLLETTIVI DELLE AMMINISTRAZIONI PUBBLICHE',
#        'num_unita': 6,
#        'addett': 115},
#       {'ateco3_code': 843,
#        'ateco3_name': 'ASSICURAZIONE SOCIALE OBBLIGATORIA',
#        'num_unita': 2,
#        'addett': 22},
#       {'ateco3_code': 851,
#        'ateco3_name': 'ISTRUZIONE PRESCOLASTICA',
#        'num_unita': 25,
#        'addett': 306},
#       {'ateco3_code': 852,
#        'ateco3_name': 'ISTRUZIONE PRIMARIA',
#        'num_unita': 12,
#        'addett': 392},
#       {'ateco3_code': 853,
#        'ateco3_name': 'ISTRUZIONE SECONDARIA',
#        'num_unita': 14,
#        'addett': 851},
#       {'ateco3_code': 855,
#        'ateco3_name': 'ALTRI SERVIZI DI ISTRUZIONE',
#        'num_unita': 21,
#        'addett': 155},
#       {'ateco3_code': 856,
#        'ateco3_name': "ATTIVITА DI SUPPORTO ALL'ISTRUZIONE",
#        'num_unita': 1,
#        'addett': 1},
#       {'ateco3_code': 861,
#        'ateco3_name': 'SERVIZI OSPEDALIERI',
#        'num_unita': 2,
#        'addett': 16},
#       {'ateco3_code': 862,
#        'ateco3_name': 'SERVIZI DEGLI STUDI MEDICI E ODONTOIATRICI',
#        'num_unita': 138,
#        'addett': 705},
#       {'ateco3_code': 869,
#        'ateco3_name': 'ALTRI SERVIZI DI ASSISTENZA SANITARIA',
#        'num_unita': 54,
#        'addett': 156},
#       {'ateco3_code': 871,
#        'ateco3_name': 'STRUTTURE DI ASSISTENZA INFERMIERISTICA RESIDENZIALE',
#        'num_unita': 1,
#        'addett': 31},
#       {'ateco3_code': 873,
#        'ateco3_name': 'STRUTTURE DI ASSISTENZA RESIDENZIALE PER ANZIANI E DISABILI',
#        'num_unita': 4,
#        'addett': 7},
#       {'ateco3_code': 879,
#        'ateco3_name': 'ALTRE STRUTTURE DI ASSISTENZA SOCIALE RESIDENZIALE',
#        'num_unita': 4,
#        'addett': 32},
#       {'ateco3_code': 889,
#        'ateco3_name': 'ALTRE ATTIVITА DI ASSISTENZA SOCIALE NON RESIDENZIALE',
#        'num_unita': 22,
#        'addett': 63},
#       {'ateco3_code': 900,
#        'ateco3_name': 'ATTIVITА CREATIVE, ARTISTICHE E DI INTRATTENIMENTO',
#        'num_unita': 34,
#        'addett': 14},
#       {'ateco3_code': 910,
#        'ateco3_name': 'ATTIVITА DI BIBLIOTECHE, ARCHIVI, MUSEI ED ALTRE ATTIVITА CULTURALI',
#        'num_unita': 21,
#        'addett': 18},
#       {'ateco3_code': 920,
#        'ateco3_name': 'ATTIVITА RIGUARDANTI LE LOTTERIE, LE SCOMMESSE, LE CASE DA GIOCO',
#        'num_unita': 13,
#        'addett': 36},
#       {'ateco3_code': 931,
#        'ateco3_name': 'ATTIVITА SPORTIVE',
#        'num_unita': 71,
#        'addett': 47},
#       {'ateco3_code': 932,
#        'ateco3_name': 'ATTIVITА RICREATIVE E DI DIVERTIMENTO',
#        'num_unita': 7,
#        'addett': 13},
#       {'ateco3_code': 941,
#        'ateco3_name': 'ATTIVITА DI ORGANIZZAZIONI ECONOMICHE, DI DATORI DI LAVORO E PROFESSIONALI',
#        'num_unita': 9,
#        'addett': 6},
#       {'ateco3_code': 942,
#        'ateco3_name': 'ATTIVITА DEI SINDACATI DI LAVORATORI DIPENDENTI',
#        'num_unita': 6,
#        'addett': 3},
#       {'ateco3_code': 949,
#        'ateco3_name': 'ATTIVITА DI ALTRE ORGANIZZAZIONI ASSOCIATIVE',
#        'num_unita': 42,
#        'addett': 8},
#       {'ateco3_code': 951,
#        'ateco3_name': 'RIPARAZIONE DI COMPUTER E DI APPARECCHIATURE PER LE COMUNICAZIONI',
#        'num_unita': 4,
#        'addett': 9},
#       {'ateco3_code': 952,
#        'ateco3_name': 'RIPARAZIONE DI BENI PER USO PERSONALE E PER LA CASA',
#        'num_unita': 19,
#        'addett': 42},
#       {'ateco3_code': 960,
#        'ateco3_name': 'ALTRE ATTIVITА DI SERVIZI PER LA PERSONA',
#        'num_unita': 166,
#        'addett': 293}]}],
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 1}},
#   'superficieEdificato': {'ouputGeotiffFile': 'http://localhost:5000/sevara/v1/jobs/readDataByArea/63/superficieEdificato.tiff',
#    'outputGeotiffFilepath': '/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/63/superficieEdificato.tiff',
#    'timeTakenInfoQuery': 0.3713693618774414,
#    'timeTakenRasterQuery': 3.3639473915100098,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'class_code': 1500,
#      'class_name': 'buildings',
#      'table_name': 'osm_buildings',
#      'total_features': 5149,
#      'layer_area': 3438097.55560937}],
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 1}},
#   'superficieAreeServizio': {'ouputGeotiffFile': 'http://localhost:5000/sevara/v1/jobs/readDataByArea/63/superficieAreeServizio.tiff',
#    'outputGeotiffFilepath': '/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/63/superficieAreeServizio.tiff',
#    'timeTakenInfoQuery': 0.03963279724121094,
#    'timeTakenRasterQuery': 0.3106107711791992,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'class_code': 7202,
#      'class_name': 'park',
#      'table_name': 'osm_landuse',
#      'total_features': 17,
#      'layer_area': 122975.209405476},
#     {'layer_id': 2,
#      'class_code': 7203,
#      'class_name': 'residential',
#      'table_name': 'osm_landuse',
#      'total_features': 2,
#      'layer_area': 10745.0729762343},
#     {'layer_id': 3,
#      'class_code': 7204,
#      'class_name': 'industrial',
#      'table_name': 'osm_landuse',
#      'total_features': 1,
#      'layer_area': 1584.97924084856},
#     {'layer_id': 4,
#      'class_code': 7206,
#      'class_name': 'cemetery',
#      'table_name': 'osm_landuse',
#      'total_features': 1,
#      'layer_area': 154594.066632306},
#     {'layer_id': 5,
#      'class_code': 7208,
#      'class_name': 'meadow',
#      'table_name': 'osm_landuse',
#      'total_features': 2,
#      'layer_area': 311.128921410711},
#     {'layer_id': 6,
#      'class_code': 7214,
#      'class_name': 'quarry',
#      'table_name': 'osm_landuse',
#      'total_features': 1,
#      'layer_area': 7581.27669248483}],
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 6}},
#   'struttureVarie': {'ouputGeotiffFile': 'http://localhost:5000/sevara/v1/jobs/readDataByArea/63/struttureVarie.tiff',
#    'outputGeotiffFilepath': '/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/63/struttureVarie.tiff',
#    'timeTakenInfoQuery': 0.06017017364501953,
#    'timeTakenRasterQuery': 0.5515127182006836,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'class_code': 2301,
#      'class_name': 'restaurant',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8355104,
#        'lon': 16.5646418,
#        'name': 'Pizzeria Mercadante'}]},
#     {'layer_id': 2,
#      'class_code': 2302,
#      'class_name': 'fast_food',
#      'table_name': 'osm_pois',
#      'total_features': 2,
#      'pois': [{'lat': 40.8288074,
#        'lon': 16.55242,
#        'name': 'Il Pizzico Pizzeria'},
#       {'lat': 40.8287736, 'lon': 16.554849, 'name': 'Pizzeria Metro Quadro'}]},
#     {'layer_id': 3,
#      'class_code': 2303,
#      'class_name': 'cafe',
#      'table_name': 'osm_pois',
#      'total_features': 5,
#      'pois': [{'lat': 40.8284951,
#        'lon': 16.5516366,
#        'name': 'Antico Castello'},
#       {'lat': 40.8291941, 'lon': 16.5500795, 'name': 'Caffè Pepe'},
#       {'lat': 40.819152, 'lon': 16.5537894, 'name': 'Caffetteria Nicolas'},
#       {'lat': 40.8311688, 'lon': 16.5554173, 'name': 'Gran Caffè Cicimarra'},
#       {'lat': 40.8320482, 'lon': 16.5570985, 'name': 'Stazione di Servizio'}]},
#     {'layer_id': 4,
#      'class_code': 2401,
#      'class_name': 'hotel',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8289539, 'lon': 16.5541038, 'name': None}]},
#     {'layer_id': 5,
#      'class_code': 2404,
#      'class_name': 'guesthouse',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8252999, 'lon': 16.5545136, 'name': 'Le Residenze'}]},
#     {'layer_id': 6,
#      'class_code': 2501,
#      'class_name': 'supermarket',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8273194, 'lon': 16.5355339, 'name': 'MD Discount'}]},
#     {'layer_id': 7,
#      'class_code': 2502,
#      'class_name': 'bakery',
#      'table_name': 'osm_pois',
#      'total_features': 3,
#      'pois': [{'lat': 40.8278839,
#        'lon': 16.5524466,
#        'name': 'Panificio del Duomo'},
#       {'lat': 40.8213391, 'lon': 16.5535238, 'name': 'Panificio del Lago'},
#       {'lat': 40.8166022, 'lon': 16.5534768, 'name': 'Panificio LaMaggiore'}]},
#     {'layer_id': 8,
#      'class_code': 2515,
#      'class_name': 'bookshop',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8278048,
#        'lon': 16.5534402,
#        'name': 'Casa Editrice Lab Edizioni'}]},
#     {'layer_id': 9,
#      'class_code': 2522,
#      'class_name': 'sports_shop',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8256493,
#        'lon': 16.5557294,
#        'name': 'Intrappola Underground Shop'}]},
#     {'layer_id': 10,
#      'class_code': 2903,
#      'class_name': 'drinking_water',
#      'table_name': 'osm_pois',
#      'total_features': 13,
#      'pois': [{'lat': 40.8233952, 'lon': 16.5601003, 'name': None},
#       {'lat': 40.8235281, 'lon': 16.5525877, 'name': None},
#       {'lat': 40.8238244, 'lon': 16.5486575, 'name': None},
#       {'lat': 40.8193109, 'lon': 16.5591805, 'name': None},
#       {'lat': 40.8228767, 'lon': 16.5548728, 'name': None},
#       {'lat': 40.83354, 'lon': 16.5527672, 'name': None},
#       {'lat': 40.8351866, 'lon': 16.5554574, 'name': None},
#       {'lat': 40.820235, 'lon': 16.5584311, 'name': None},
#       {'lat': 40.8315127, 'lon': 16.5557416, 'name': None},
#       {'lat': 40.8320377, 'lon': 16.5472654, 'name': None},
#       {'lat': 40.8289557, 'lon': 16.5510385, 'name': None},
#       {'lat': 40.8290171, 'lon': 16.551805, 'name': None},
#       {'lat': 40.8276589, 'lon': 16.5526683, 'name': None}]},
#     {'layer_id': 11,
#      'class_code': 2904,
#      'class_name': 'fountain',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8325526, 'lon': 16.5569918, 'name': None}]},
#     {'layer_id': 12,
#      'class_code': 2101,
#      'class_name': 'pharmacy',
#      'table_name': 'osm_pois',
#      'total_features': 1,
#      'pois': [{'lat': 40.8320199,
#        'lon': 16.5525343,
#        'name': 'dott. Tricarico'}]},
#     {'layer_id': 13,
#      'class_code': 2120,
#      'class_name': 'doctors',
#      'table_name': 'osm_pois',
#      'total_features': 3,
#      'pois': [{'lat': 40.8323439,
#        'lon': 16.5515225,
#        'name': 'Centro DCA "Salvatore Cotugno"'},
#       {'lat': 40.8264671,
#        'lon': 16.5564974,
#        'name': 'Studio Medico Mastrorilli'},
#       {'lat': 40.8264908,
#        'lon': 16.5567756,
#        'name': 'Studio Medico Mastrorilli'}]}],
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 13}},
#   'pericolositaFrane': {'ouputGeotiffFile': 'http://localhost:5000/sevara/v1/jobs/readDataByArea/63/pericolositaFrane.tiff',
#    'outputGeotiffFilepath': '/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/63/pericolositaFrane.tiff',
#    'timeTakenInfoQuery': 0.07904720306396484,
#    'timeTakenRasterQuery': 0.22434639930725098,
#    'time_units': 'Seconds',
#    'layers': [{'layer_id': 1,
#      'layer_name': 'Molto elevata P4',
#      'table_name': 'isp_frane',
#      'layer_area': 18680.4924145876},
#     {'layer_id': 2,
#      'layer_name': 'Aree di Attenzione AA',
#      'table_name': 'isp_frane',
#      'layer_area': 55077.7019170589}],
#    'total_area': 73758.19433164649,
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 2}},
#   'pericolositaIdraulica': {'ouputGeotiffFile': None,
#    'outputGeotiffFilepath': None,
#    'timeTakenInfoQuery': 0.33555102348327637,
#    'timeTakenRasterQuery': 0,
#    'time_units': 'Seconds',
#    'layers': [],
#    'total_area': 0,
#    'rasterInfo': {'cellSizeX_Meters': 10,
#     'cellSizeY_meters': 10,
#     'cellSizeX_dd': 0.00012156329728595376,
#     'cellSizeY_dd': 6.363224449097722e-05,
#     'Rows': -361,
#     'Cols': -510,
#     'Bands': 0}}},
#  'outputsToProduce': ['attivita',
#   'superficieEdificato',
#   'superficieAreeServizio',
#   'struttureVarie',
#   'pericolositaFrane',
#   'pericolositaIdraulica'],
#  'rasterInfoCommon': {'cellSizeX_Meters': 10,
#   'cellSizeY_meters': 10,
#   'cellSizeX_dd': 0.00012156329728595376,
#   'cellSizeY_dd': 6.363224449097722e-05,
#   'Rows': -361,
#   'Cols': -510},
#  'time_taken_total': 25.48502540588379,
#  'time_units': 'Seconds'}

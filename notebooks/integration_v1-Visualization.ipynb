# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# %%
os.__file__
# Out:
# '/home/sandy/anaconda3/envs/geo/lib/python3.7/os.py'

# %%
sys.path.append(os.path.abspath('../src/'))

# %%
from postgis_raster_bridge.visualization import visualize_image

# %%
import glob
import time

# %%
ims = glob.glob('/home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/*.tiff')

# %%
im = ims[0]
print(im)
visualize_image(im)
# Out:
# /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/superficieEdificato.tiff
# Found 1 bands in raster /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/superficieEdificato.tiff

# %%
im = ims[1]
print(im)
visualize_image(im)
# Out:
# /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/superficieAreeServizio.tiff
# Found 15 bands in raster /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/superficieAreeServizio.tiff

# %%
im = ims[2]
print(im)
visualize_image(im)
# Out:
# /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/attivita.tiff
# Found 1 bands in raster /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/attivita.tiff

# %%
im = ims[3]
print(im)
visualize_image(im)
# Out:
# /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/struttureVarie.tiff
# Found 60 bands in raster /home/sandy/workspace/mario ricci/2-postgis2raster-sud-v2/sevara_jobs/31/struttureVarie.tiff
